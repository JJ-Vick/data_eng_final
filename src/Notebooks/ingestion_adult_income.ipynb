# %%
import pandas as pd
from pathlib import Path

# %%
CLEANED_CSV = Path("../raw/adult_income_clean.csv")

CLEANED_CSV.exists()
# Out:
# True

# %%
df = pd.read_csv(CLEANED_CSV)

df.head(3)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital_status         occupation   relationship     race      sex  \
# 0       Never-married       Adm-clerical  Not-in-family  Unknown     Male
# 1  Married-civ-spouse    Exec-managerial        Husband    White     Male
# 2            Divorced  Handlers-cleaners  Not-in-family    White  Unknown
#
#    capital_gain  capital_loss  hours_per_week native_country income  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
#
#   source_split
# 0        train
# 1        train
# 2        train

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE         COMMAND                  CREATED          STATUS          PORTS                                         NAMES
# b750b421b3c8   adminer       "entrypoint.sh docke…"   23 minutes ago   Up 22 minutes   0.0.0.0:8080->8080/tcp, [::]:8080->8080/tcp   adminer_container
# 9a6ae3bbc7ed   postgres:15   "docker-entrypoint.s…"   23 minutes ago   Up 22 minutes   0.0.0.0:5432->5432/tcp, [::]:5432->5432/tcp   project_db_container

# %%
# !docker cp ../raw/adult_income_clean.csv project_db_container:/adult_income_clean.csv

# %%
df.to_csv(
    "../raw/adult_income_clean_postgres.csv",
    index=False,
    sep=","
)

# %%
# !docker cp ../raw/adult_income_clean_postgres.csv project_db_container:/adult_income_clean_postgres.csv
